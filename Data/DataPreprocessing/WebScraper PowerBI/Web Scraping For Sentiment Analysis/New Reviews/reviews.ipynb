# %%
#import pandas module
import pandas as pd
import os
import glob

# %%
#list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['Atlantic Technological University - Donegal Letterkenny Campus.csv',
#  "Carlow College, St Patrick's,.csv",
#  'Dublin Business Schoo;.csv',
#  'Dundalk IT.csv',
#  'Griffith College.csv',
#  'Munster TU.csv',
#  'NCI Reviews Google.csv',
#  'NUIG.csv',
#  'South East Technological University.csv',
#  'TUS.csv',
#  'University Limeric.csv']

# %%
df_append = pd.DataFrame()
#append all files together
for file in csv_files:
            df_temp = pd.read_csv(file)
            df_append = df_append.append(df_temp, ignore_index=True)
df_append
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13736\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13736\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13736\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13736\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13736\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13736\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13736\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13736\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13736\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13736\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13736\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
#                 author                                         reviewBody  \
# 0           nora coyle  Very efficient and all staff were very profess...
# 1               SJK JO   Good University with world class infrastructure.
# 2        Riaran Coarty  Been here before for an evening course, good c...
# 3          Anna Carnie                      Treated beautifully thank you
# 4    Micheal O Herlihy                     Getting the vaccine, well run!
# ..                 ...                                                ...
# 205      Michael Quinn  Excellent scenery with beautiful walking areas...
# 206     Marian English  My wife and I have been to UCH Limerick on sev...
# 207      Padraig Glynn  Beautiful campus. Wonderful faculty. Great cou...
# 208       Théo Equenot  Terrible since Covid-19 (except teachers). If ...
# 209        eileen Finn  I was snorkel training with UL sac in the deep...
#
#      reviewRating  ratingMaxvalue  reviewTags   dateCreated images  \
# 0             5.0             5.0         NaN    a year ago    NaN
# 1             5.0             5.0         NaN   2 weeks ago    NaN
# 2             4.0             5.0         NaN   5 years ago    NaN
# 3             5.0             5.0         NaN    a year ago    NaN
# 4             5.0             5.0         NaN    a year ago    NaN
# ..            ...             ...         ...           ...    ...
# 205           5.0             5.0         NaN   2 weeks ago    NaN
# 206           4.0             5.0         NaN   a month ago    NaN
# 207           5.0             5.0         NaN   a month ago    NaN
# 208           1.0             5.0         NaN  2 months ago    NaN
# 209           5.0             5.0         NaN   a month ago    NaN
#
#                                              reviewUrl    reviewSource  \
# 0    https://www.google.com/maps/contrib/1106014847...  www.google.com
# 1    https://www.google.com/maps/contrib/1111317017...  www.google.com
# 2    https://www.google.com/maps/contrib/1137990747...  www.google.com
# 3    https://www.google.com/maps/contrib/1049020099...  www.google.com
# 4    https://www.google.com/maps/contrib/1048563138...  www.google.com
# ..                                                 ...             ...
# 205  https://www.google.com/maps/contrib/1127806466...  www.google.com
# 206  https://www.google.com/maps/contrib/1182047674...  www.google.com
# 207  https://www.google.com/maps/contrib/1181044566...  www.google.com
# 208  https://www.google.com/maps/contrib/1135026344...  www.google.com
# 209  https://www.google.com/maps/contrib/1098097946...  www.google.com
#
#      originalText                                               name  \
# 0             NaN  Atlantic Technological University - Donegal Le...
# 1             NaN  Atlantic Technological University - Donegal Le...
# 2             NaN  Atlantic Technological University - Donegal Le...
# 3             NaN  Atlantic Technological University - Donegal Le...
# 4             NaN  Atlantic Technological University - Donegal Le...
# ..            ...                                                ...
# 205           NaN                             University of Limerick
# 206           NaN                             University of Limerick
# 207           NaN                             University of Limerick
# 208           NaN                             University of Limerick
# 209           NaN                             University of Limerick
#
#      reviewCount  aggregateRating  \
# 0            121              4.7
# 1            121              4.7
# 2            121              4.7
# 3            121              4.7
# 4            121              4.7
# ..           ...              ...
# 205          433              4.7
# 206          433              4.7
# 207          433              4.7
# 208          433              4.7
# 209          433              4.7
#
#                                                address  \
# 0    Port Rd, Gortlee, Letterkenny, County Donegal,...
# 1    Port Rd, Gortlee, Letterkenny, County Donegal,...
# 2    Port Rd, Gortlee, Letterkenny, County Donegal,...
# 3    Port Rd, Gortlee, Letterkenny, County Donegal,...
# 4    Port Rd, Gortlee, Letterkenny, County Donegal,...
# ..                                                 ...
# 205               Castletroy, County Limerick, Ireland
# 206               Castletroy, County Limerick, Ireland
# 207               Castletroy, County Limerick, Ireland
# 208               Castletroy, County Limerick, Ireland
# 209               Castletroy, County Limerick, Ireland
#
#                         place_id  \
# 0    ChIJndjQejrrX0gRDv2EVl8_qCc
# 1    ChIJndjQejrrX0gRDv2EVl8_qCc
# 2    ChIJndjQejrrX0gRDv2EVl8_qCc
# 3    ChIJndjQejrrX0gRDv2EVl8_qCc
# 4    ChIJndjQejrrX0gRDv2EVl8_qCc
# ..                           ...
# 205  ChIJc1guIZheW0gRLfzDqvPrf8o
# 206  ChIJc1guIZheW0gRLfzDqvPrf8o
# 207  ChIJc1guIZheW0gRLfzDqvPrf8o
# 208  ChIJc1guIZheW0gRLfzDqvPrf8o
# 209  ChIJc1guIZheW0gRLfzDqvPrf8o
#
#                                                  input  \
# 0    https://www.google.com/search?q=atlantic+techn...
# 1    https://www.google.com/search?q=atlantic+techn...
# 2    https://www.google.com/search?q=atlantic+techn...
# 3    https://www.google.com/search?q=atlantic+techn...
# 4    https://www.google.com/search?q=atlantic+techn...
# ..                                                 ...
# 205  https://www.google.com/search?q=university+of+...
# 206  https://www.google.com/search?q=university+of+...
# 207  https://www.google.com/search?q=university+of+...
# 208  https://www.google.com/search?q=university+of+...
# 209  https://www.google.com/search?q=university+of+...
#
#                                            businessUrl
# 0    https://www.google.com/maps/place/?q=place_id:...
# 1    https://www.google.com/maps/place/?q=place_id:...
# 2    https://www.google.com/maps/place/?q=place_id:...
# 3    https://www.google.com/maps/place/?q=place_id:...
# 4    https://www.google.com/maps/place/?q=place_id:...
# ..                                                 ...
# 205  https://www.google.com/maps/place/?q=place_id:...
# 206  https://www.google.com/maps/place/?q=place_id:...
# 207  https://www.google.com/maps/place/?q=place_id:...
# 208  https://www.google.com/maps/place/?q=place_id:...
# 209  https://www.google.com/maps/place/?q=place_id:...
#
# [210 rows x 17 columns]

# %%
df_append.to_csv('new_reviews.csv')
