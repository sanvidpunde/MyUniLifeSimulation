# %%
#import pandas module
import pandas as pd
import os
import glob

# %%
#list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['ExistingReviews.csv', 'new_reviews.csv']

# %%
df_append = pd.DataFrame()
#append all files together
for file in csv_files:
            df_temp = pd.read_csv(file, sep = ',' ,encoding='cp437', on_bad_lines='skip')
            df_append = df_append.append(df_temp, ignore_index=True)
df_append
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13776\614171196.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_13776\614171196.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
#                author                                         reviewBody  \
# 0        Dermot Dunne  Stunning new university campus near Dublin cit...
# 1    jorge garcia rey  Great campus to go for a walk, and with a coup...
# 2        Omar Nicolai  I know this building has over 200 years of var...
# 3       ruth connolly  Great place to sit or exercise. Well kept safe...
# 4      Fintan Moloney  Nice college grounds area for walking, jogging...
# ..                ...                                                ...
# 538     Michael Quinn  Excellent scenery with beautiful walking areas...
# 539    Marian English  My wife and I have been to UCH Limerick on sev...
# 540     Padraig Glynn  Beautiful campus. Wonderful faculty. Great cou...
# 541           Equenot  Terrible since Covid-19 (except teachers). If ...
# 542       eileen Finn  I was snorkel training with UL sac in the deep...
#
#      reviewRating  ratingMaxvalue   dateCreated  \
# 0             5.0             5.0          2014
# 1             5.0             5.0          2014
# 2             5.0             5.0          2014
# 3             5.0             5.0          2014
# 4             5.0             5.0          2014
# ..            ...             ...           ...
# 538           5.0             5.0   2 weeks ago
# 539           4.0             5.0   a month ago
# 540           5.0             5.0   a month ago
# 541           1.0             5.0  2 months ago
# 542           5.0             5.0   a month ago
#
#                                              reviewUrl    reviewSource  \
# 0    https://www.google.com/maps/contrib/1172180627...  www.google.com
# 1    https://www.google.com/maps/contrib/1018313073...  www.google.com
# 2    https://www.google.com/maps/contrib/1069724274...  www.google.com
# 3    https://www.google.com/maps/contrib/1090465921...  www.google.com
# 4    https://www.google.com/maps/contrib/1052988761...  www.google.com
# ..                                                 ...             ...
# 538  https://www.google.com/maps/contrib/1127806466...  www.google.com
# 539  https://www.google.com/maps/contrib/1182047674...  www.google.com
# 540  https://www.google.com/maps/contrib/1181044566...  www.google.com
# 541  https://www.google.com/maps/contrib/1135026344...  www.google.com
# 542  https://www.google.com/maps/contrib/1098097946...  www.google.com
#
#                           name                               address Sentiment
# 0    TU Dublin, Aungier Street             TU Dublin, Aungier Street  Positive
# 1    TU Dublin, Aungier Street             TU Dublin, Aungier Street  Positive
# 2    TU Dublin, Aungier Street             TU Dublin, Aungier Street  Positive
# 3    TU Dublin, Aungier Street             TU Dublin, Aungier Street  Positive
# 4    TU Dublin, Aungier Street             TU Dublin, Aungier Street  Positive
# ..                         ...                                   ...       ...
# 538     University of Limerick  Castletroy, County Limerick, Ireland       NaN
# 539     University of Limerick  Castletroy, County Limerick, Ireland       NaN
# 540     University of Limerick  Castletroy, County Limerick, Ireland       NaN
# 541     University of Limerick  Castletroy, County Limerick, Ireland       NaN
# 542     University of Limerick  Castletroy, County Limerick, Ireland       NaN
#
# [543 rows x 10 columns]

# %%
df_append.head()
# Out:
#              author                                         reviewBody  \
# 0      Dermot Dunne  Stunning new university campus near Dublin cit...
# 1  jorge garcia rey  Great campus to go for a walk, and with a coup...
# 2      Omar Nicolai  I know this building has over 200 years of var...
# 3     ruth connolly  Great place to sit or exercise. Well kept safe...
# 4    Fintan Moloney  Nice college grounds area for walking, jogging...
#
#    reviewRating  ratingMaxvalue dateCreated  \
# 0           5.0             5.0        2014
# 1           5.0             5.0        2014
# 2           5.0             5.0        2014
# 3           5.0             5.0        2014
# 4           5.0             5.0        2014
#
#                                            reviewUrl    reviewSource  \
# 0  https://www.google.com/maps/contrib/1172180627...  www.google.com
# 1  https://www.google.com/maps/contrib/1018313073...  www.google.com
# 2  https://www.google.com/maps/contrib/1069724274...  www.google.com
# 3  https://www.google.com/maps/contrib/1090465921...  www.google.com
# 4  https://www.google.com/maps/contrib/1052988761...  www.google.com
#
#                         name                    address Sentiment
# 0  TU Dublin, Aungier Street  TU Dublin, Aungier Street  Positive
# 1  TU Dublin, Aungier Street  TU Dublin, Aungier Street  Positive
# 2  TU Dublin, Aungier Street  TU Dublin, Aungier Street  Positive
# 3  TU Dublin, Aungier Street  TU Dublin, Aungier Street  Positive
# 4  TU Dublin, Aungier Street  TU Dublin, Aungier Street  Positive

# %%
df_append.to_csv('finalReviews.csv')
