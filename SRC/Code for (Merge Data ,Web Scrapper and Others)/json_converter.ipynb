# %%
import pandas as pd

# %%
df = pd.read_csv("Cork_College_Courses.csv", encoding= 'unicode_escape')
df.head()
# Out:
#                             college  \
# 0  Munster Technological University
# 1  Munster Technological University
# 2  Munster Technological University
# 3  Munster Technological University
# 4  Munster Technological University
#
#                                               course   code  \
# 0            Agriculture - Clonakilty / Cork Campus   MT750
# 1  Analytical & Pharmaceutical Chemistry - Cork C...  MT774
# 2  Analytical Chemistry with Quality Assurance - ...  MT874
# 3               Information Technology - Cork Campus  MT705
# 4   Automotive Technology & Management - Cork Campus  MT747
#
#                                                title    course_type  \
# 0             Agriculture - Clonakilty / Cork Campus  Undergradaute
# 1  Analytical & Pharmaceutical Chemistry - Cork C...  Undergradaute
# 2  Analytical Chemistry with Quality Assurance - ...  Undergradaute
# 3               Information Technology - Cork Campus  Undergradaute
# ...

# %%
prof_json = df.to_json("Cork_College_Courses.json")
